# %%
#두 자연수 10와 5가 주어진다.
#이때, A+B, A-B, A*B, A/B(몫), A%B(나머지)를 출력하는 프로그램을 작성하시오

A=10
B=5
print(A+B)
print(A-B)
print(A*B)
print(A/B)
print(A%B)
# Out:
# 15
# 5
# 50
# 2.0
# 0

# %%
#가로 12, 세로 7인 직사각형의 넓이와 둘레를 구하시오

a=12
b=7
print(a*b)
print((2*a)+(2*b))
# Out:
# 84
# 38

# %%
#국어 88, 영어 92, 수학 75인 학생의 과목 평균을 구하시오
a=88
b=92
c=75
print((a+b+c)/3)
# Out:
# 85.0
